# %%
import pandas as pd

# %%
data1 = pd.read_csv('product_datasets/한국소비자원 생필품 가격데이터 2023년 6월.csv', encoding = 'cp949')
data2 = pd.read_csv('product_datasets/한국소비자원 생필품 가격데이터 2023년 7월.csv', encoding = 'cp949')
data3 = pd.read_csv('product_datasets/한국소비자원 생필품 가격데이터 2023년 8월.csv', encoding = 'cp949')

# %%
result = pd.concat([data1, data2, data3])

# %%
data1
# Out:
#                        상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0            머거본 알땅콩(135g)  2023-06-02  2700  신세계백화점죽전점   머거본  NaN   NaN
# 1            머거본 알땅콩(135g)  2023-06-02  3900     CU(본사)   머거본  NaN   NaN
# 2            머거본 알땅콩(135g)  2023-06-02  2500  세븐일레븐(본사)   머거본    N     N
# 3            허니버터아몬드(210g)  2023-06-02  7900  현대백화점디큐브점  길림양행  NaN   NaN
# 4            허니버터아몬드(210g)  2023-06-02  7900   현대백화점대구점  길림양행  NaN   NaN
# ...                    ...         ...   ...        ...   ...  ...   ...
# 166902  쇠고기 불고기(1등급, 100g)  2023-06-16  4990    롯데슈퍼가락점   불고기    N     N
# 166903  쇠고기 불고기(1등급, 100g)  2023-06-16  4990   롯데슈퍼G철원점   불고기    N     N
# 166904  쇠고기 불고기(1등급, 100g)  2023-06-16  4990   롯데슈퍼G춘천점   불고기    N     N
# 166905  쇠고기 불고기(1등급, 100g)  2023-06-16  4990   롯데슈퍼G홍제점   불고기    N     N
# 166906  쇠고기 불고기(1등급, 100g)  2023-06-16  4990   롯데슈퍼G전곡점   불고기    N     N
#
# [166907 rows x 7 columns]

# %%
data2
# Out:
#                        상품명         조사일  판매가격         판매업소   제조사 세일여부 원플러스원
# 0            머거본 알땅콩(135g)  2023-07-07  3900       CU(본사)   머거본  NaN   NaN
# 1            머거본 알땅콩(135g)  2023-07-07  2700    신세계백화점죽전점   머거본  NaN   NaN
# 2            허니버터아몬드(210g)  2023-07-07  7900      현대백화점본점  길림양행  NaN   NaN
# 3            허니버터아몬드(210g)  2023-07-07  7900     현대백화점신촌점  길림양행  NaN   NaN
# 4            허니버터아몬드(210g)  2023-07-07  7990       이마트광주점  길림양행  NaN   NaN
# ...                    ...         ...   ...          ...   ...  ...   ...
# 169634  쇠고기 불고기(1등급, 100g)  2023-07-21  4990      롯데슈퍼중촌점   불고기    N     N
# 169635  쇠고기 불고기(1등급, 100g)  2023-07-21  4990     롯데슈퍼한마음점   불고기    N     N
# 169636  쇠고기 불고기(1등급, 100g)  2023-07-21  4990      롯데슈퍼한빛점   불고기    N     N
# 169637  쇠고기 불고기(1등급, 100g)  2023-07-21  4990  롯데슈퍼프리미엄공덕점   불고기    N     N
# 169638  쇠고기 불고기(1등급, 100g)  2023-07-21  4990  롯데슈퍼프리미엄도곡점   불고기    N     N
#
# [169639 rows x 7 columns]

# %%
data3
# Out:
#                        상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0            머거본 알땅콩(135g)  2023-08-04  2500  세븐일레븐(본사)   머거본    N     N
# 1            머거본 알땅콩(135g)  2023-08-04  2700  신세계백화점죽전점   머거본  NaN   NaN
# 2            머거본 알땅콩(135g)  2023-08-04  3900     CU(본사)   머거본  NaN   NaN
# 3            허니버터아몬드(210g)  2023-08-04  7990     이마트울산점  길림양행  NaN   NaN
# 4            허니버터아몬드(210g)  2023-08-04  6300  세븐일레븐(본사)  길림양행    N     N
# ...                    ...         ...   ...        ...   ...  ...   ...
# 158486  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼효자점   불고기    N     N
# 158487  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼보령점   불고기    N     N
# 158488  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼삼천점   불고기    N     N
# 158489  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼율량점   불고기    N     N
# 158490  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼창천점   불고기    N     N
#
# [158491 rows x 7 columns]

# %%
result
# Out:
#                        상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0            머거본 알땅콩(135g)  2023-06-02  2700  신세계백화점죽전점   머거본  NaN   NaN
# 1            머거본 알땅콩(135g)  2023-06-02  3900     CU(본사)   머거본  NaN   NaN
# 2            머거본 알땅콩(135g)  2023-06-02  2500  세븐일레븐(본사)   머거본    N     N
# 3            허니버터아몬드(210g)  2023-06-02  7900  현대백화점디큐브점  길림양행  NaN   NaN
# 4            허니버터아몬드(210g)  2023-06-02  7900   현대백화점대구점  길림양행  NaN   NaN
# ...                    ...         ...   ...        ...   ...  ...   ...
# 158486  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼효자점   불고기    N     N
# 158487  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼보령점   불고기    N     N
# 158488  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼삼천점   불고기    N     N
# 158489  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼율량점   불고기    N     N
# 158490  쇠고기 불고기(1등급, 100g)  2023-08-18  4990    롯데슈퍼창천점   불고기    N     N
#
# [495037 rows x 7 columns]

# %%
result.to_csv('product_datasets/생필품6,7,8월가격데이터.csv', encoding='utf-8-sig')
